# %% [markdown]
# http://www.psmsl.org/data/obtaining/stations/23.php

# %%
import pandas
import requests
import io
import matplotlib.pyplot as plt

# %%
url = 'http://www.psmsl.org/data/obtaining/rlr.monthly.data/23.rlrdata'

# %%
print requests.get(url).content[:100]
# Out:
#   1865.0416;  6814; 0;000
#   1865.1250;  6589; 0;000
#   1865.2084;  6519; 0;000
#   1865.2916;  6529; 0;

# %%
# in memory file
f = io.BytesIO(requests.get(url).content)
df = pandas.read_csv(f, sep=';', names=('year', 'waterlevel', 'code', 'another code'))
df.head()
# Out:
#         year  waterlevel  code  another code
# 0  1865.0416        6814     0             0
# 1  1865.1250        6589     0             0
# 2  1865.2084        6519     0             0
# 3  1865.2916        6529     0             0
# 4  1865.3750        6679     0             0
#
# [5 rows x 4 columns]

# %%
fig, ax = plt.subplots()
plt.plot(df['year'], df['waterlevel'])
ax.set_ylabel('water level [mm]')
ax.set_xlabel('year')

# %%
import statsmodels.api as sm

# %%
y = df['waterlevel']
X = df['year']
X = sm.add_constant(X)

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             waterlevel   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     544.3
# Date:                Mon, 19 May 2014   Prob (F-statistic):          3.25e-105
# Time:                        22:36:19   Log-Likelihood:                -10933.
# No. Observations:                1776   AIC:                         2.187e+04
# Df Residuals:                    1774   BIC:                         2.188e+04
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       3971.2635    122.950     32.300      0.000      3730.122  4212.405
# year           1.4789      0.063     23.330      0.000         1.355     1.603
# ==============================================================================
# Omnibus:                       17.573   Durbin-Watson:                   1.274
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.050
# Skew:                           0.224   Prob(JB):                     0.000120
# Kurtosis:                       3.209   Cond. No.                     8.80e+04
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 8.8e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
def fit(startyear):
    df_selected = df[df['year'] > startyear]
    y = df_selected['waterlevel']
    X = df_selected['year']
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    print(results.summary())

# %%
from IPython.html.widgets import interact

# %%
interact(fit, startyear=(1860, 1980, 10))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             waterlevel   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     4.578
# Date:                Mon, 19 May 2014   Prob (F-statistic):             0.0330
# Time:                        22:40:20   Log-Likelihood:                -2448.6
# No. Observations:                 396   AIC:                             4901.
# Df Residuals:                     394   BIC:                             4909.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       4283.4192   1238.181      3.459      0.001      1849.151  6717.687
# year           1.3269      0.620      2.140      0.033         0.108     2.546
# ==============================================================================
# Omnibus:                        4.115   Durbin-Watson:                   1.157
# Prob(Omnibus):                  0.128   Jarque-Bera (JB):                3.861
# Skew:                           0.211   Prob(JB):                        0.145
# Kurtosis:                       3.237   Cond. No.                     4.18e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 4.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
def plot(startyear):
    df_selected = df[df['year'] > startyear]
    y = df_selected['waterlevel']
    X = df_selected['year']
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    fig, ax = plt.subplots()
    ax.plot(df['year'], df['waterlevel'], '.', alpha=0.1)
    ax.plot(df_selected['year'], results.fittedvalues)
    
    ax.set_ylim(6400,7300)

# %%
interact(plot, startyear=(1860, 1980, 10))

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std


def plot(startyear):
    df_selected = df[df['year'] > startyear]
    y = df_selected['waterlevel']
    X = df_selected['year']
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    fig, ax = plt.subplots()
    ax.plot(df['year'], df['waterlevel'], '.', alpha=0.1)
    ax.plot(df_selected['year'], results.fittedvalues)
    fit, lower, upper = wls_prediction_std(results)
    plt.fill_between(df_selected['year'], lower, upper, alpha=0.3)
    
    ax.set_ylim(6400,7300)

# %%
interact(plot, startyear=(1860, 1980, 10))

# %%
# %load_ext rmagic

# %%
# %Rpush df

# %%
def test(startyear):
    df_selected = df[df['year']>startyear]
    # %Rpush df_selected
    # %R print(ggplot(df, aes(year, waterlevel)) + geom_point(alpha=0.3) + stat_smooth(data=df_selected, method='lm'))
interact(test, startyear=(1860, 1980, 10))

# %%
# %%R
# print(
#     ggplot(df, aes(year, waterlevel))
#        + geom_point(alpha=0.3)
#        + stat_smooth(data=df, method='loess')
# )

# %%
def plot(startyear):
    df_selected = df[(df['year'] >= startyear) & (df['year'] < (startyear + 18.6*2))]
    
    y = df_selected['waterlevel']
    X = np.c_[df_selected['year']-1970, (df_selected['year']-1970)**2]
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    fig, ax = plt.subplots()
    ax.plot(df['year'], df['waterlevel'], '.', alpha=0.3)
    ax.plot(df_selected['year'], results.fittedvalues, linewidth=5)

# %%
interact(plot, startyear=(1860, 1980, 5))

# %%
def plot(startyear):
    df_selected = df[(df['year'] >= startyear) & (df['year'] < (startyear + 18.6*3))]
    
    y = df_selected['waterlevel']
    X = np.c_[
        df_selected['year']-1970, 
        np.cos(2*np.pi*(df_selected['year']-1970)/18.613),
        np.sin(2*np.pi*(df_selected['year']-1970)/18.613)

    ]
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    fig, ax = plt.subplots()
    ax.plot(df['year'], df['waterlevel'], '.', alpha=0.3)
    ax.plot(df_selected['year'], results.fittedvalues, linewidth=5)

# %%
interact(plot, startyear=(1860, 1980, 5))
