# %% [markdown]
# - http://www.psmsl.org/data/obtaining/stations/23.php Den Helder
# - http://www.psmsl.org/data/obtaining/stations/32.php IJmuiden

# %%
# %matplotlib inline
import pandas
import requests
import io
import matplotlib.pyplot as plt
import numpy as np

# %%
url = 'http://www.psmsl.org/data/obtaining/rlr.monthly.data/32.rlrdata'

# %%
print requests.get(url).content[:100]
# Out:
#   1871.3750;  6799; 0;000
#   1871.4584;  6939; 0;000
#   1871.5416;  6959; 0;000
#   1871.6250;  6859; 0;

# %%
# in memory file
f = io.BytesIO(requests.get(url).content)
df = pandas.read_csv(f, sep=';', names=('year', 'waterlevel', 'code', 'another code'))
df.head()
# Out:
#         year  waterlevel  code  another code
# 0  1871.3750        6799     0             0
# 1  1871.4584        6939     0             0
# 2  1871.5416        6959     0             0
# 3  1871.6250        6859     0             0
# 4  1871.7084        6919     0             0

# %%
fig, ax = plt.subplots()
plt.plot(df['year'], df['waterlevel'])
ax.set_ylabel('water level [mm]')
ax.set_xlabel('year')

# %%
import statsmodels.api as sm

# %%
y = df['waterlevel']
X = df['year']
X = sm.add_constant(X)

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             waterlevel   R-squared:                       0.253
# Model:                            OLS   Adj. R-squared:                  0.252
# Method:                 Least Squares   F-statistic:                     578.9
# Date:                Fri, 08 Aug 2014   Prob (F-statistic):          2.08e-110
# Time:                        14:31:00   Log-Likelihood:                -10528.
# No. Observations:                1712   AIC:                         2.106e+04
# Df Residuals:                    1710   BIC:                         2.107e+04
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       3749.1797    129.314     28.993      0.000      3495.550  4002.809
# year           1.6012      0.067     24.060      0.000         1.471     1.732
# ==============================================================================
# Omnibus:                        4.559   Durbin-Watson:                   1.132
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                4.516
# Skew:                           0.125   Prob(JB):                        0.105
# Kurtosis:                       3.021   Cond. No.                     9.17e+04
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 9.17e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
def fit(startyear):
    df_selected = df[df['year'] > startyear]
    y = df_selected['waterlevel']
    X = df_selected['year']
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    print(results.summary())

# %%
from IPython.html.widgets import interact

# %%
interact(fit, startyear=(1860, 1980, 10))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             waterlevel   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     324.5
# Date:                Fri, 08 Aug 2014   Prob (F-statistic):           5.93e-64
# Time:                        14:31:00   Log-Likelihood:                -6906.8
# No. Observations:                1128   AIC:                         1.382e+04
# Df Residuals:                    1126   BIC:                         1.383e+04
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       2600.2461    238.507     10.902      0.000      2132.279  3068.214
# year           2.1842      0.121     18.015      0.000         1.946     2.422
# ==============================================================================
# Omnibus:                        3.817   Durbin-Watson:                   1.237
# Prob(Omnibus):                  0.148   Jarque-Bera (JB):                4.060
# Skew:                           0.070   Prob(JB):                        0.131
# Kurtosis:                       3.258   Cond. No.                     1.43e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.43e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# <function __main__.fit>

# %%
def plot(startyear):
    df_selected = df[df['year'] > startyear]
    y = df_selected['waterlevel']
    X = df_selected['year']
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    fig, ax = plt.subplots()
    ax.plot(df['year'], df['waterlevel'], '.', alpha=0.1)
    ax.plot(df_selected['year'], results.fittedvalues)
    
    ax.set_ylim(6400,7300)

# %%
interact(plot, startyear=(1860, 1980, 10))
# Out:
# <function __main__.plot>

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std


def plot(startyear):
    df_selected = df[df['year'] > startyear]
    y = df_selected['waterlevel']
    X = df_selected['year']
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    fig, ax = plt.subplots()
    ax.plot(df['year'], df['waterlevel'], '.', alpha=0.1)
    ax.plot(df_selected['year'], results.fittedvalues)
    fit, lower, upper = wls_prediction_std(results)
    plt.fill_between(df_selected['year'], lower, upper, alpha=0.3)
    
    ax.set_ylim(6400,7300)

# %%
interact(plot, startyear=(1860, 1980, 10))
# Out:
# <function __main__.plot>

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %Rpush df
# %R library('ggplot2')
# Out:
# <StrVector - Python:0x112934b90 / R:0x7febbd025e98>
# [str, str, str, ..., str, str, str]

# %%
def test(startyear):
    df_selected = df[df['year']>startyear]
    # %Rpush df_selected
    # %R print(ggplot(df, aes(year, waterlevel)) + geom_point(alpha=0.3) + stat_smooth(data=df_selected, method='loess'))
interact(test, startyear=(1860, 1980, 10))

# %%
def plot(startyear):
    df_selected = df[(df['year'] >= startyear) & (df['year'] < (startyear + 18.6*2))]
    
    y = df_selected['waterlevel']
    X = np.c_[df_selected['year']-1970, (df_selected['year']-1970)**2]
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    fig, ax = plt.subplots()
    ax.plot(df['year'], df['waterlevel'], '.', alpha=0.3)
    ax.plot(df_selected['year'], results.fittedvalues, linewidth=5)

# %%
interact(plot, startyear=(1860, 1980, 5))
# Out:
# <function __main__.plot>

# %%
def plot(startyear):
    n_periods = 5
    df_selected = df[(df['year'] >= startyear) & (df['year'] < (startyear + 18.6*n_periods))]
    
    y = df_selected['waterlevel']
    X = np.c_[
        df_selected['year']-1970, 
        np.cos(2*np.pi*(df_selected['year']-1970)/18.613),
        np.sin(2*np.pi*(df_selected['year']-1970)/18.613)

    ]
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    results = model.fit()
    # e^{i\theta} = \cos\theta + i\sin\theta
    phase = np.angle(complex(results.params['x2'], results.params['x3']))
    ampl = np.sqrt(results.params['x2']**2 + results.params['x3']**2)
    
    # plot it
    fig, ax = plt.subplots()
    ax.set_title("Phase (rad): %.1f, amplitude: %.1f" % (phase, ampl))
    ax.plot(df['year'], df['waterlevel'], '.', alpha=0.3)
    ax.plot(df_selected['year'], results.fittedvalues, linewidth=5)

# %%
interact(plot, startyear=(1860, 1980, 5))
